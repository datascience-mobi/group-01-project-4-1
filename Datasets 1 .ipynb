# %%
import scanpy as sc
import numpy as np
import pandas as pd
import pylab as pl
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns 

# Allows jupyter to display plots inside notebooks
# %matplotlib inline

# This will make Jupyter display the plots as vector graphics
# %config InlineBackend.figure_format = 'svg'

# %%
from sklearn.datasets import make_moons
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
import time
from sklearn import cluster, datasets
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from sklearn.datasets.samples_generator import make_blobs

# %%
np.random.seed(0)#macht die zufälligen Zahlen reproduzierbar

# %%
n_samples = 1500

# %%
moondata = datasets.make_moons(n_samples = n_samples, noise = 0.5)

# %%
listmd = list(moondata)

# %%
print(listmd)
# Out:
# [array([[-0.23725702,  1.13471818],
#        [ 0.34207319,  1.19838577],
#        [ 2.48308857,  0.48171595],
#        ...,
#        [ 1.53859349, -0.55458338],
#        [-0.23375778,  1.25953709],
#        [-0.33522183, -0.46740013]]), array([0, 0, 1, ..., 1, 0, 0], dtype=int64)]

# %%
print(moondata)
# Out:
# (array([[-0.23725702,  1.13471818],
#        [ 0.34207319,  1.19838577],
#        [ 2.48308857,  0.48171595],
#        ...,
#        [ 1.53859349, -0.55458338],
#        [-0.23375778,  1.25953709],
#        [-0.33522183, -0.46740013]]), array([0, 0, 1, ..., 1, 0, 0], dtype=int64))

# %%
X,y = make_blobs(n_samples = n_samples, centers = 3, n_features = 2)

# %%
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a542f22c2cae> in <module>
# ----> 1 df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
#
# NameError: name 'DataFrame' is not defined

# %%
from pandas import DataFrame

# %%
df = DataFrame(dict(x=X[:,0], y = X[:,1], label = y))

# %%
colors = {0:'red', 1:'blue', 2:'green'}

# %%
fig, ax = pyplot.subplots()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-f01bc0568a5a> in <module>
# ----> 1 fig, ax = pyplot.subplots()
#
# NameError: name 'pyplot' is not defined

# %%
from matplotlib import pyplot

# %%
fig, ax = pyplot.subplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-36b9451b3a1d> in <module>
# ----> 1 fig, ax = pyplot.subplot()
#
# TypeError: cannot unpack non-iterable AxesSubplot object

# %%
from sklearn.datasets.samples_generator import make_blobs
from matplotlib import pyplot
from pandas import DataFrame
# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=3, n_features=2)
# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue', 2:'green'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

# %%
 type(df)
# Out:
# pandas.core.frame.DataFrame
